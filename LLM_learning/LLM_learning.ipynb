# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ## Representing Language as Bag of Words

# %% [markdown]
# ![bag_of_words.png](attachment:7afbcaaa-99bc-4328-ba3f-472b05f5d472.png)

# %% [markdown]
# * Representation of text into numbers
# * Ignores semantic nature or meaning of text

# %% [markdown]
# ## Better Representations with Dense Vector Embeddings (word2vec)

# %% [markdown]
# ![word_2_vec.png](attachment:8d68edd4-0555-4948-94b7-8118bf3d02b7.png)

# %% [markdown]
# * Leverages neural networks
# * Predict neighbors in a sentence or relationship between words

# %% [markdown]
# ![neighbors_predict.png](attachment:b451760f-446f-47f0-ae08-cf95f2b3bbd2.png)

# %% [markdown]
# ### Various Embeddings

# %% [markdown]
# ![representation_embedding.png](attachment:80706b3a-93b6-4819-96ab-c1ea9856b6b9.png)

# %% [markdown]
# # Encoding and Decoding Context with Attention

# %% [markdown]
# ![rnn_enc_dec.png](attachment:a5b27a2f-e7fa-4423-9579-a89f08f04eca.png)

# %% [markdown]
# <html>
#     <h2>Two Tasks</h2>
#     <ul>
#         <li>Encoding (Representing an input sequence)</li>
#         <li>Decoding (Generating output sequence)</li>
#     </ul>
# </html>

# %% [markdown]
# <h2>Autoregressive</h2>

# %% [markdown]
# ![autoregressive.png](attachment:5889bd56-5d56-448e-9e6f-f4c1016e8fdf.png)

# %% [markdown]
# <html>
#     <h3>Encoding step</h3>
#     <ul>
#         <li>Aims to represent the input as well as possible</li>
#         <li> Generates context in form of an embedding</li>
#         <li>Input for the decoder</li>
#         <li>Dealing with longer sentences gets difficult</li>
#     </ul>
# </html>

# %% [markdown]
# <h2>Attention</h2>

# %% [markdown]
# ![attention.png](attachment:7dd0692f-5e06-4625-9b29-81ba003f0306.png)

# %% [markdown]
# <ul>
#     <li>Allows a model to focus on relevant parts of input sequence</li>
# </ul>

# %% [markdown]
# ![decoder_rnn.png](attachment:2354b479-b8cf-4f3b-a69d-b996c572f275.png)

# %% [markdown]
# <h2>Transformers</h2>

# %% [markdown]
# ![transformer.png](attachment:c8ba1c2f-fb40-4e60-b44f-c5cdd26dea74.png)

# %% [markdown]
# <h1>Representation Models: Encoder-Only Models</h1>
# <h2> BERT : Bidirectional Encoder Representation from Transformers</h2>

# %% [markdown]
# ![bert.png](attachment:c0514d2f-160d-4aee-8ef3-108d4369ab52.png)

# %% [markdown]
# <h1>Transfer Learning</h1>

# %% [markdown]
# ![fine_tune_bert.png](attachment:f2afbd5d-adc4-4105-95ad-b4163f2af290.png)
